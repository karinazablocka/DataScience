# %%
import sys
from bs4 import BeautifulSoup
import urllib.request
from IPython.display import HTML
import re

import nltk

import pandas as pd

# %%
address = "https://www.countryliving.com/gardening/garden-ideas/g29814701/trees-for-small-gardens/"
address = urllib.request.urlopen(address).read()

soup = BeautifulSoup(address, "lxml")

# %%
soup_no_p = soup.find_all("p")

# %%
soup_no_p
# Out:
# [<p class="affiliate-disclaimer-detail">
#  		Country Living editors select each product featured. If you buy from a link, we may earn a commission.
#
#  					<a data-vars-ga-outbound-link="https://www.countryliving.com/about/a707/contact-us/" href="https://www.countryliving.com/about/a707/contact-us/" target="_blank">More about us.</a>
#  </p>,
#  <p>Because good things really do come in small packages.</p>,
#  <p>If you don’t have room in your yard for a mighty maple tree or a towering oak tree, plant a more compact tree instead! Small-space trees pack as much visual punch as their larger siblings, and they often boast gorgeous spring flowers and vibrant autumn colors too. That's why we've rounded up the best trees for small gardens right here. </p>,
#  <p>To give your new tree a good start in life, dig a hole about twice as wide as the root ball or container, but only deep enough so it sits an inch or two above ground level (<a data-vars-ga-outbound-link="https://extension.oregonstate.edu/news/get-help-selecting-planting-tree-touch-finger" href="https://extension.oregonstate.edu/news/get-help-selecting-planting-tree-touch-finger" target="_blank">planting too deep</a> is a common mistake!). Remove burlap, wire, and twine from the root ball (because they interfere with root growth) and don’t decompose (nope, not even burlap). Spread out the roots in the hole, refill around the tree, and tamp down. <a data-vars-ga-outbound-link="https://hgic.clemson.edu/factsheet/planting-trees-correctly/" href="https://hgic.clemson.edu/factsheet/planting-trees-correctly/" target="_blank">Don’t put potting soil or other additives in the hole</a>; that just encourages roots to circle around inside the hole, rather than stretching out into the native soil. Water your tree well, and mulch. But don’t mound mulch up against the trunk (which is called volcano mulching), because it invites disease and insect damage. <br/></p>,
#  <p>Whether you have a tiny urban garden or a <a data-vars-ga-outbound-link="https://www.countryliving.com/gardening/news/g4183/small-backyard-ideas/" href="https://www.countryliving.com/gardening/news/g4183/small-backyard-ideas/">small backyard</a>, here are a few of our favorite small trees to plant. (Check out our <a data-vars-ga-outbound-link="https://www.countryliving.com/gardening/garden-ideas/advice/g746/garden-plans/" href="https://www.countryliving.com/gardening/garden-ideas/advice/g746/garden-plans/">best garden plans</a> and <a data-vars-ga-outbound-link="https://www.countryliving.com/gardening/g26753835/indoor-trees/" href="https://www.countryliving.com/gardening/g26753835/indoor-trees/">best indoor trees</a> too!)</p>,
#  <p>Showy clusters of fragrant white or blush-pink flowers make this tree a real showstopper in the spring. The weeping variety is even more stunning!</p>,
#  <p><strong>Height at maturity:</strong> About 15 to 20 feet  </p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 8</p>,
#  <p><a class="body-btn-link" data-vars-ga-call-to-action="SHOP FLOWERING CHERRY TREES" data-vars-ga-outbound-link="https://www.monrovia.com/plant-catalog/plants/2011/mount-fuji-japanese-flowering-cherry/" href="https://www.monrovia.com/plant-catalog/plants/2011/mount-fuji-japanese-flowering-cherry/" rel="nofollow" target="_blank">SHOP FLOWERING CHERRY TREES</a><br/></p>,
#  <p>Huge spring flowers, showy red fruit that birds love, and gorgeous fall colors are the reasons why dogwoods have always been popular in gardens across the country. Many different varieties, including new hybrids that are more disease-resistant, exist. </p>,
#  <p><strong>Height at maturity:</strong> About 15 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 9</p>,
#  <p><a class="body-btn-link product-links-button" data-affiliate="true" data-vars-ga-call-to-action="SHOP DOGWOOD TREES" data-vars-ga-outbound-link="https://www.homedepot.com/p/Spring-Hill-Nurseries-White-Flowers-Milkyway-Dogwood-Cornus-Tree-Live-Bareroot-Tree-1-Pack-60968/308907157" data-vars-ga-product-brand="Spring Hill Nurseries" data-vars-ga-product-id="1aa9af7b-2bfa-4721-a56d-453aa75dcb7f" data-vars-ga-product-price="59.98" data-vars-ga-product-sem3-brand="Spring Hill Nurseries" data-vars-ga-product-sem3-category="Flowers" data-vars-ga-product-sem3-id="7lzL9DBNbsAUQMcqI2OEYm" href="https://go.redirectingat.com/?id=74968X1525072&amp;xs=1&amp;url=https%3A%2F%2Fwww.homedepot.com%2Fp%2FSpring-Hill-Nurseries-White-Flowers-Milkyway-Dogwood-Cornus-Tree-Live-Bareroot-Tree-1-Pack-60968%2F308907157&amp;sref=https%3A%2F%2Fwww.countryliving.com%2Fgardening%2Fgarden-ideas%2Fg29814701%2Ftrees-for-small-gardens%2F%3Fpre%3Dgardening%252Fgarden-ideas%252F%26prefix%3Dg%26id%3D29814701%26del%3D%26variantId%3D%26post%3D%252Ftrees-for-small-gardens" rel="nofollow" target="_blank">SHOP DOGWOOD TREES</a><br/></p>,
#  <p>These eye-catching trees have delicate foliage, interesting bark, and elegant, arching limbs. Foliage comes in an array of shades from pale green to deep burgundy. Most varieties prefer part shade. </p>,
#  <p><strong>Height at maturity:</strong> 15 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 8</p>,
#  <p><a class="body-btn-link" data-affiliate="true" data-vars-ga-call-to-action="SHOP JAPANESE MAPLE TREES" data-vars-ga-outbound-link="https://www.springhillnursery.com/product/crimson-queen-japanese-maple" href="https://go.redirectingat.com/?id=74968X1525072&amp;xs=1&amp;url=https%3A%2F%2Fwww.springhillnursery.com%2Fproduct%2Fcrimson-queen-japanese-maple&amp;sref=https%3A%2F%2Fwww.countryliving.com%2Fgardening%2Fgarden-ideas%2Fg29814701%2Ftrees-for-small-gardens%2F%3Fpre%3Dgardening%252Fgarden-ideas%252F%26prefix%3Dg%26id%3D29814701%26del%3D%26variantId%3D%26post%3D%252Ftrees-for-small-gardens" rel="nofollow" target="_blank">SHOP JAPANESE MAPLE TREES</a><br/></p>,
#  <p>This lesser-known maple is absolutely stunning with cinnamon-brown peeling bark and an oval to rounded canopy shape. Plant it near your deck or patio so you can appreciate its unique charm.</p>,
#  <p><strong>Height at maturity:</strong> About 25 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 8</p>,
#  <p><a class="body-btn-link product-links-button" data-affiliate="true" data-vars-ga-call-to-action="SHOP PAPERBARK MAPLE TREES" data-vars-ga-outbound-link="https://www.amazon.com/Acer-Griseum-Paperbark-maple-tree/dp/B0012LDB2K/ref=sr_1_1?" data-vars-ga-product-brand="Herter Nursery" data-vars-ga-product-id="74a27d17-f00b-4762-bbd9-f85a6ebe5af1" data-vars-ga-product-price="22.50" data-vars-ga-product-sem3-brand="Herter Nursery" data-vars-ga-product-sem3-category="Trees" data-vars-ga-product-sem3-id="" href="https://www.amazon.com/Acer-Griseum-Paperbark-maple-tree/dp/B0012LDB2K/ref=sr_1_1?" rel="nofollow" target="_blank">SHOP PAPERBARK MAPLE TREES</a></p>,
#  <p>This small tree has fragrant clusters of white flowers that become purple berries in fall. You can make jam from them, or share them with the wildlife! </p>,
#  <p><strong>Height at maturity:</strong> About 25 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 4 to 9</p>,
#  <p><a class="body-btn-link" data-affiliate="true" data-vars-ga-call-to-action="SHOP SERVICEBERRY TREES" data-vars-ga-outbound-link="https://www.springhillnursery.com/product/standing-ovation-serviceberry" href="https://go.redirectingat.com/?id=74968X1525072&amp;xs=1&amp;url=https%3A%2F%2Fwww.springhillnursery.com%2Fproduct%2Fstanding-ovation-serviceberry&amp;sref=https%3A%2F%2Fwww.countryliving.com%2Fgardening%2Fgarden-ideas%2Fg29814701%2Ftrees-for-small-gardens%2F%3Fpre%3Dgardening%252Fgarden-ideas%252F%26prefix%3Dg%26id%3D29814701%26del%3D%26variantId%3D%26post%3D%252Ftrees-for-small-gardens" rel="nofollow" target="_blank">SHOP SERVICEBERRY TREES</a></p>,
#  <p>Dense branches, dazzling deep purple-red flowers in spring, and tiny fruit make the cold-hardy crabapple a favorite as an accent in the garden or planted in groups. </p>,
#  <p><strong>Height at maturity:</strong> About 15 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 3 to 9</p>,
#  <p><a class="body-btn-link product-links-button" data-affiliate="true" data-vars-ga-call-to-action="SHOP CRABAPPLE TREES" data-vars-ga-outbound-link="https://www.amazon.com/Online-Orchards-Prairie-Flowering-Crabapple/dp/B07K83ZL4H/ref=sr_1_2?" data-vars-ga-product-brand="Online Orchards" data-vars-ga-product-id="7661d700-b249-490c-9b45-369387f72748" data-vars-ga-product-price="29.99" data-vars-ga-product-sem3-brand="Online Orchards" data-vars-ga-product-sem3-category="Trees" data-vars-ga-product-sem3-id="" href="https://www.amazon.com/Online-Orchards-Prairie-Flowering-Crabapple/dp/B07K83ZL4H/ref=sr_1_2?" rel="nofollow" target="_blank">SHOP CRABAPPLE TREES</a></p>,
#  <p>Once only known by plant collectors, this multi-stemmed tree is becoming more popular because of its year-round beauty. It boasts distinctive curling leaves, peeling bark, and fragrant white flowers that become twisted red bracts. Pollinators love it!</p>,
#  <p><strong>Height at maturity:</strong> About 10 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 9</p>,
#  <p><a class="body-btn-link" data-vars-ga-call-to-action="SHOP SEVEN-SON FLOWER TREES" data-vars-ga-outbound-link="https://www.provenwinners.com/plants/heptacodium/temple-bloom-seven-son-flower-heptacodium-miconioides" href="https://www.provenwinners.com/plants/heptacodium/temple-bloom-seven-son-flower-heptacodium-miconioides" rel="nofollow" target="_blank">SHOP SEVEN-SON FLOWER TREES</a></p>,
#  <p>This star of the Southern landscape has dark bark, glossy leaves, and vibrant fall colors. Its showy, frilly flowers come in every shade from pure white to hot pink. </p>,
#  <p><strong>Height at maturity:</strong> About 10 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 6 to 10</p>,
#  <p><a class="body-btn-link" data-affiliate="true" data-vars-ga-call-to-action="SHOP CREPE MYRTLE TREES" data-vars-ga-outbound-link="https://www.amazon.com/Natchez-White-Crapemyrtle-Tree-California/dp/B0066AF1CA/ref=sr_1_18?" href="https://www.amazon.com/Natchez-White-Crapemyrtle-Tree-California/dp/B0066AF1CA/ref=sr_1_18?" rel="nofollow" target="_blank">SHOP CREPE MYRTLE TREES</a></p>,
#  <p>Clusters of airy, smoke-like seeds with reddish foliage that turns to orange in fall make this a beautiful accent tree. It holds its color all season long.</p>,
#  <p><strong>Height at maturity:</strong> About 15 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 4 to 8</p>,
#  <p><a class="body-btn-link" data-vars-ga-call-to-action="SHOP SMOKE TREES" data-vars-ga-outbound-link="https://www.provenwinners.com/plants/cotinus/winecraft-gold-smokebush-cotinus-coggygria" href="https://www.provenwinners.com/plants/cotinus/winecraft-gold-smokebush-cotinus-coggygria" rel="nofollow" target="_blank">SHOP SMOKE TREES</a></p>,
#  <p>Teeny-tiny pink or purple flowers cling to the bare branches of this native charmer in early spring. The pretty heart-shaped leaves are reddish or golden, depending on the variety.  </p>,
#  <p><strong>Height at maturity:</strong> About 10 to 20 feet</p>,
#  <p><strong>USDA Hardiness Zones:</strong> 5 to 9</p>,
#  <p><a class="body-btn-link product-links-button" data-affiliate="true" data-vars-ga-call-to-action="SHOP REDBUD TREES" data-vars-ga-outbound-link="https://www.lowes.com/pd/3-25-Gallon-Pink-Redbud-Flowering-Tree-in-Pot-With-Soil-L11838/3633842" data-vars-ga-product-brand="" data-vars-ga-product-id="19251be8-5ef4-44e4-bff3-13b4c74110c2" data-vars-ga-product-price="26.98" data-vars-ga-product-sem3-brand="" data-vars-ga-product-sem3-category="Patio &amp; Garden" data-vars-ga-product-sem3-id="6qyToXFvpAyESG2WCyM8y0" href="https://go.redirectingat.com/?id=74968X1525072&amp;xs=1&amp;url=https%3A%2F%2Fwww.lowes.com%2Fpd%2F3-25-Gallon-Pink-Redbud-Flowering-Tree-in-Pot-With-Soil-L11838%2F3633842&amp;sref=https%3A%2F%2Fwww.countryliving.com%2Fgardening%2Fgarden-ideas%2Fg29814701%2Ftrees-for-small-gardens%2F%3Fpre%3Dgardening%252Fgarden-ideas%252F%26prefix%3Dg%26id%3D29814701%26del%3D%26variantId%3D%26post%3D%252Ftrees-for-small-gardens" rel="nofollow" target="_blank">SHOP REDBUD TREES</a></p>]

# %%
text_only = []

for i in soup_no_p:
    a = i.get_text()
    text_only.append(a)

text_only = str(text_only)

# %%
text_only
# Out:
# '[\'\\n\\t\\tCountry Living editors select each product featured. If you buy from a link, we may earn a commission.\\n\\n\\t\\t\\t\\t\\tMore about us.\\n\', \'Because good things really do come in small packages.\', "If you don’t have room in your yard for a mighty maple tree or a towering oak tree, plant a more compact tree instead! Small-space trees pack as much visual punch as their larger siblings, and they often boast gorgeous spring flowers and vibrant autumn colors too. That\'s why we\'ve rounded up the best trees for small gardens right here. ", \'To give your new tree a good start in life, dig a hole about twice as wide as the root ball or container, but only deep enough so it sits an inch or two above ground level (planting too deep is a common mistake!). Remove burlap, wire, and twine from the root ball (because they interfere with root growth) and don’t decompose (nope, not even burlap). Spread out the roots in the hole, refill around the tree, and tamp down. Don’t put potting soil or other additives in the hole; that just encourages roots to circle around inside the hole, rather than stretching out into the native soil. Water your tree well, and mulch. But don’t mound mulch up against the trunk (which is called volcano mulching), because it invites disease and insect damage. \', \'Whether you have a tiny urban garden or a small backyard, here are a few of our favorite small trees to plant. (Check out our best garden plans and best indoor trees too!)\', \'Showy clusters of fragrant white or blush-pink flowers make this tree a real showstopper in the spring. The weeping variety is even more stunning!\', \'Height at maturity: About 15 to 20 feet  \', \'USDA Hardiness Zones: 5 to 8\', \'SHOP FLOWERING CHERRY TREES\', \'Huge spring flowers, showy red fruit that birds love, and gorgeous fall colors are the reasons why dogwoods have always been popular in gardens across the country. Many different varieties, including new hybrids that are more disease-resistant, exist. \', \'Height at maturity: About 15 to 20 feet\', \'USDA Hardiness Zones: 5 to 9\', \'SHOP DOGWOOD TREES\', \'These eye-catching trees have delicate foliage, interesting bark, and elegant, arching limbs. Foliage comes in an array of shades from pale green to deep burgundy. Most varieties prefer part shade. \', \'Height at maturity: 15 to 20 feet\', \'USDA Hardiness Zones: 5 to 8\', \'SHOP JAPANESE MAPLE TREES\', \'This lesser-known maple is absolutely stunning with cinnamon-brown peeling bark and an oval to rounded canopy shape. Plant it near your deck or patio so you can appreciate its unique charm.\', \'Height at maturity: About 25 feet\', \'USDA Hardiness Zones: 5 to 8\', \'SHOP PAPERBARK MAPLE TREES\', \'This small tree has fragrant clusters of white flowers that become purple berries in fall. You can make jam from them, or share them with the wildlife! \', \'Height at maturity: About 25 feet\', \'USDA Hardiness Zones: 4 to 9\', \'SHOP SERVICEBERRY TREES\', \'Dense branches, dazzling deep purple-red flowers in spring, and tiny fruit make the cold-hardy crabapple a favorite as an accent in the garden or planted in groups. \', \'Height at maturity: About 15 to 20 feet\', \'USDA Hardiness Zones: 3 to 9\', \'SHOP CRABAPPLE TREES\', \'Once only known by plant collectors, this multi-stemmed tree is becoming more popular because of its year-round beauty. It boasts distinctive curling leaves, peeling bark, and fragrant white flowers that become twisted red bracts. Pollinators love it!\', \'Height at maturity: About 10 to 20 feet\', \'USDA Hardiness Zones: 5 to 9\', \'SHOP SEVEN-SON FLOWER TREES\', \'This star of the Southern landscape has dark bark, glossy leaves, and vibrant fall colors. Its showy, frilly flowers come in every shade from pure white to hot pink. \', \'Height at maturity: About 10 to 20 feet\', \'USDA Hardiness Zones: 6 to 10\', \'SHOP CREPE MYRTLE TREES\', \'Clusters of airy, smoke-like seeds with reddish foliage that turns to orange in fall ma ...

# %%
from nltk.tokenize import word_tokenize
word_tk = word_tokenize(text_only)
print("Word tokenizing the text: \n")
print(word_tk)
# Out:
# Word tokenizing the text:
#
# ['[', "'\\n\\t\\tCountry", 'Living', 'editors', 'select', 'each', 'product', 'featured', '.', 'If', 'you', 'buy', 'from', 'a', 'link', ',', 'we', 'may', 'earn', 'a', 'commission.\\n\\n\\t\\t\\t\\t\\tMore', 'about', 'us.\\n', "'", ',', "'Because", 'good', 'things', 'really', 'do', 'come', 'in', 'small', 'packages', '.', "'", ',', '``', 'If', 'you', 'don', '’', 't', 'have', 'room', 'in', 'your', 'yard', 'for', 'a', 'mighty', 'maple', 'tree', 'or', 'a', 'towering', 'oak', 'tree', ',', 'plant', 'a', 'more', 'compact', 'tree', 'instead', '!', 'Small-space', 'trees', 'pack', 'as', 'much', 'visual', 'punch', 'as', 'their', 'larger', 'siblings', ',', 'and', 'they', 'often', 'boast', 'gorgeous', 'spring', 'flowers', 'and', 'vibrant', 'autumn', 'colors', 'too', '.', 'That', "'s", 'why', 'we', "'ve", 'rounded', 'up', 'the', 'best', 'trees', 'for', 'small', 'gardens', 'right', 'here', '.', '``', ',', "'To", 'give', 'your', 'new', 'tree', 'a', 'good', 'start', 'in', 'life', ',', 'dig', 'a', 'hole', 'about', 'twice', 'as', 'wide', 'as', 'the', 'root', 'ball', 'or', 'container', ',', 'but', 'only', 'deep', 'enough', 'so', 'it', 'sits', 'an', 'inch', 'or', 'two', 'above', 'ground', 'level', '(', 'planting', 'too', 'deep', 'is', 'a', 'common', 'mistake', '!', ')', '.', 'Remove', 'burlap', ',', 'wire', ',', 'and', 'twine', 'from', 'the', 'root', 'ball', '(', 'because', 'they', 'interfere', 'with', 'root', 'growth', ')', 'and', 'don', '’', 't', 'decompose', '(', 'nope', ',', 'not', 'even', 'burlap', ')', '.', 'Spread', 'out', 'the', 'roots', 'in', 'the', 'hole', ',', 'refill', 'around', 'the', 'tree', ',', 'and', 'tamp', 'down', '.', 'Don', '’', 't', 'put', 'potting', 'soil', 'or', 'other', 'additives', 'in', 'the', 'hole', ';', 'that', 'just', 'encourages', 'roots', 'to', 'circle', 'around', 'inside', 'the', 'hole', ',', 'rather', 'than', 'stretching', 'out', 'into', 'the', 'native', 'soil', '.', 'Water', 'your', 'tree', 'well', ',', 'and', 'mulch', '.', 'But', 'don', '’', 't', 'mound', 'mulch', 'up', 'against', 'the', 'trunk', '(', 'which', 'is', 'called', 'volcano', 'mulching', ')', ',', 'because', 'it', 'invites', 'disease', 'and', 'insect', 'damage', '.', "'", ',', "'Whether", 'you', 'have', 'a', 'tiny', 'urban', 'garden', 'or', 'a', 'small', 'backyard', ',', 'here', 'are', 'a', 'few', 'of', 'our', 'favorite', 'small', 'trees', 'to', 'plant', '.', '(', 'Check', 'out', 'our', 'best', 'garden', 'plans', 'and', 'best', 'indoor', 'trees', 'too', '!', ')', "'", ',', "'Showy", 'clusters', 'of', 'fragrant', 'white', 'or', 'blush-pink', 'flowers', 'make', 'this', 'tree', 'a', 'real', 'showstopper', 'in', 'the', 'spring', '.', 'The', 'weeping', 'variety', 'is', 'even', 'more', 'stunning', '!', "'", ',', "'Height", 'at', 'maturity', ':', 'About', '15', 'to', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', 'to', '8', "'", ',', "'SHOP", 'FLOWERING', 'CHERRY', 'TREES', "'", ',', "'Huge", 'spring', 'flowers', ',', 'showy', 'red', 'fruit', 'that', 'birds', 'love', ',', 'and', 'gorgeous', 'fall', 'colors', 'are', 'the', 'reasons', 'why', 'dogwoods', 'have', 'always', 'been', 'popular', 'in', 'gardens', 'across', 'the', 'country', '.', 'Many', 'different', 'varieties', ',', 'including', 'new', 'hybrids', 'that', 'are', 'more', 'disease-resistant', ',', 'exist', '.', "'", ',', "'Height", 'at', 'maturity', ':', 'About', '15', 'to', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', 'to', '9', "'", ',', "'SHOP", 'DOGWOOD', 'TREES', "'", ',', "'These", 'eye-catching', 'trees', 'have', 'delicate', 'foliage', ',', 'interesting', 'bark', ',', 'and', 'elegant', ',', 'arching', 'limbs', '.', 'Foliage', 'comes', 'in', 'an', 'array', 'of', 'shades', 'from', 'pale', 'green', 'to', 'deep', 'burgundy', '.', 'Most', 'varieties', 'prefer', 'part', 'shade', '.', "'", ',', "'Height", 'at', 'maturity', ':', '15', 'to', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', 'to', '8', "'", ',', "'SHOP", 'JAPANESE', 'MAPLE', 'TREES', "'" ...

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
sw = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Karina.Zablocka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filtered_words = [w for w in word_tk if not w in sw]

print("The text after removing stop words: \n")
print(filtered_words)
# Out:
# The text after removing stop words:
#
# ['[', "'\\n\\t\\tCountry", 'Living', 'editors', 'select', 'product', 'featured', '.', 'If', 'buy', 'link', ',', 'may', 'earn', 'commission.\\n\\n\\t\\t\\t\\t\\tMore', 'us.\\n', "'", ',', "'Because", 'good', 'things', 'really', 'come', 'small', 'packages', '.', "'", ',', '``', 'If', '’', 'room', 'yard', 'mighty', 'maple', 'tree', 'towering', 'oak', 'tree', ',', 'plant', 'compact', 'tree', 'instead', '!', 'Small-space', 'trees', 'pack', 'much', 'visual', 'punch', 'larger', 'siblings', ',', 'often', 'boast', 'gorgeous', 'spring', 'flowers', 'vibrant', 'autumn', 'colors', '.', 'That', "'s", "'ve", 'rounded', 'best', 'trees', 'small', 'gardens', 'right', '.', '``', ',', "'To", 'give', 'new', 'tree', 'good', 'start', 'life', ',', 'dig', 'hole', 'twice', 'wide', 'root', 'ball', 'container', ',', 'deep', 'enough', 'sits', 'inch', 'two', 'ground', 'level', '(', 'planting', 'deep', 'common', 'mistake', '!', ')', '.', 'Remove', 'burlap', ',', 'wire', ',', 'twine', 'root', 'ball', '(', 'interfere', 'root', 'growth', ')', '’', 'decompose', '(', 'nope', ',', 'even', 'burlap', ')', '.', 'Spread', 'roots', 'hole', ',', 'refill', 'around', 'tree', ',', 'tamp', '.', 'Don', '’', 'put', 'potting', 'soil', 'additives', 'hole', ';', 'encourages', 'roots', 'circle', 'around', 'inside', 'hole', ',', 'rather', 'stretching', 'native', 'soil', '.', 'Water', 'tree', 'well', ',', 'mulch', '.', 'But', '’', 'mound', 'mulch', 'trunk', '(', 'called', 'volcano', 'mulching', ')', ',', 'invites', 'disease', 'insect', 'damage', '.', "'", ',', "'Whether", 'tiny', 'urban', 'garden', 'small', 'backyard', ',', 'favorite', 'small', 'trees', 'plant', '.', '(', 'Check', 'best', 'garden', 'plans', 'best', 'indoor', 'trees', '!', ')', "'", ',', "'Showy", 'clusters', 'fragrant', 'white', 'blush-pink', 'flowers', 'make', 'tree', 'real', 'showstopper', 'spring', '.', 'The', 'weeping', 'variety', 'even', 'stunning', '!', "'", ',', "'Height", 'maturity', ':', 'About', '15', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', '8', "'", ',', "'SHOP", 'FLOWERING', 'CHERRY', 'TREES', "'", ',', "'Huge", 'spring', 'flowers', ',', 'showy', 'red', 'fruit', 'birds', 'love', ',', 'gorgeous', 'fall', 'colors', 'reasons', 'dogwoods', 'always', 'popular', 'gardens', 'across', 'country', '.', 'Many', 'different', 'varieties', ',', 'including', 'new', 'hybrids', 'disease-resistant', ',', 'exist', '.', "'", ',', "'Height", 'maturity', ':', 'About', '15', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', '9', "'", ',', "'SHOP", 'DOGWOOD', 'TREES', "'", ',', "'These", 'eye-catching', 'trees', 'delicate', 'foliage', ',', 'interesting', 'bark', ',', 'elegant', ',', 'arching', 'limbs', '.', 'Foliage', 'comes', 'array', 'shades', 'pale', 'green', 'deep', 'burgundy', '.', 'Most', 'varieties', 'prefer', 'part', 'shade', '.', "'", ',', "'Height", 'maturity', ':', '15', '20', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', '8', "'", ',', "'SHOP", 'JAPANESE', 'MAPLE', 'TREES', "'", ',', "'This", 'lesser-known', 'maple', 'absolutely', 'stunning', 'cinnamon-brown', 'peeling', 'bark', 'oval', 'rounded', 'canopy', 'shape', '.', 'Plant', 'near', 'deck', 'patio', 'appreciate', 'unique', 'charm', '.', "'", ',', "'Height", 'maturity', ':', 'About', '25', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '5', '8', "'", ',', "'SHOP", 'PAPERBARK', 'MAPLE', 'TREES', "'", ',', "'This", 'small', 'tree', 'fragrant', 'clusters', 'white', 'flowers', 'become', 'purple', 'berries', 'fall', '.', 'You', 'make', 'jam', ',', 'share', 'wildlife', '!', "'", ',', "'Height", 'maturity', ':', 'About', '25', 'feet', "'", ',', "'USDA", 'Hardiness', 'Zones', ':', '4', '9', "'", ',', "'SHOP", 'SERVICEBERRY', 'TREES', "'", ',', "'Dense", 'branches', ',', 'dazzling', 'deep', 'purple-red', 'flowers', 'spring', ',', 'tiny', 'fruit', 'make', 'cold-hardy', 'crabapple', 'favorite', 'accent', 'garden', 'planted', 'groups', '.', "'", ',', "'Height", 'maturity', ':', 'About', '15', '20', 'feet', "'", ' ...

# %%
filtered_words_lower = []

for i in filtered_words:
    i = i.lower()
    filtered_words_lower.append(i)
    

filtered_words = filtered_words_lower

# %%
filtered_words
# Out:
# ['[',
#  "'\\n\\t\\tcountry",
#  'living',
#  'editors',
#  'select',
#  'product',
#  'featured',
#  '.',
#  'if',
#  'buy',
#  'link',
#  ',',
#  'may',
#  'earn',
#  'commission.\\n\\n\\t\\t\\t\\t\\tmore',
#  'us.\\n',
#  "'",
#  ',',
#  "'because",
#  'good',
#  'things',
#  'really',
#  'come',
#  'small',
#  'packages',
#  '.',
#  "'",
#  ',',
#  '``',
#  'if',
#  '’',
#  'room',
#  'yard',
#  'mighty',
#  'maple',
#  'tree',
#  'towering',
#  'oak',
#  'tree',
#  ',',
#  'plant',
#  'compact',
#  'tree',
#  'instead',
#  '!',
#  'small-space',
#  'trees',
#  'pack',
#  'much',
#  'visual',
#  'punch',
#  'larger',
#  'siblings',
#  ',',
#  'often',
#  'boast',
#  'gorgeous',
#  'spring',
#  'flowers',
#  'vibrant',
#  'autumn',
#  'colors',
#  '.',
#  'that',
#  "'s",
#  "'ve",
#  'rounded',
#  'best',
#  'trees',
#  'small',
#  'gardens',
#  'right',
#  '.',
#  '``',
#  ',',
#  "'to",
#  'give',
#  'new',
#  'tree',
#  'good',
#  'start',
#  'life',
#  ',',
#  'dig',
#  'hole',
#  'twice',
#  'wide',
#  'root',
#  'ball',
#  'container',
#  ',',
#  'deep',
#  'enough',
#  'sits',
#  'inch',
#  'two',
#  'ground',
#  'level',
#  '(',
#  'planting',
#  'deep',
#  'common',
#  'mistake',
#  '!',
#  ')',
#  '.',
#  'remove',
#  'burlap',
#  ',',
#  'wire',
#  ',',
#  'twine',
#  'root',
#  'ball',
#  '(',
#  'interfere',
#  'root',
#  'growth',
#  ')',
#  '’',
#  'decompose',
#  '(',
#  'nope',
#  ',',
#  'even',
#  'burlap',
#  ')',
#  '.',
#  'spread',
#  'roots',
#  'hole',
#  ',',
#  'refill',
#  'around',
#  'tree',
#  ',',
#  'tamp',
#  '.',
#  'don',
#  '’',
#  'put',
#  'potting',
#  'soil',
#  'additives',
#  'hole',
#  ';',
#  'encourages',
#  'roots',
#  'circle',
#  'around',
#  'inside',
#  'hole',
#  ',',
#  'rather',
#  'stretching',
#  'native',
#  'soil',
#  '.',
#  'water',
#  'tree',
#  'well',
#  ',',
#  'mulch',
#  '.',
#  'but',
#  '’',
#  'mound',
#  'mulch',
#  'trunk',
#  '(',
#  'called',
#  'volcano',
#  'mulching',
#  ')',
#  ',',
#  'invites',
#  'disease',
#  'insect',
#  'damage',
#  '.',
#  "'",
#  ',',
#  "'whether",
#  'tiny',
#  'urban',
#  'garden',
#  'small',
#  'backyard',
#  ',',
#  'favorite',
#  'small',
#  'trees',
#  'plant',
#  '.',
#  '(',
#  'check',
#  'best',
#  'garden',
#  'plans',
#  'best',
#  'indoor',
#  'trees',
#  '!',
#  ')',
#  "'",
#  ',',
#  "'showy",
#  'clusters',
#  'fragrant',
#  'white',
#  'blush-pink',
#  'flowers',
#  'make',
#  'tree',
#  'real',
#  'showstopper',
#  'spring',
#  '.',
#  'the',
#  'weeping',
#  'variety',
#  'even',
#  'stunning',
#  '!',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '15',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '8',
#  "'",
#  ',',
#  "'shop",
#  'flowering',
#  'cherry',
#  'trees',
#  "'",
#  ',',
#  "'huge",
#  'spring',
#  'flowers',
#  ',',
#  'showy',
#  'red',
#  'fruit',
#  'birds',
#  'love',
#  ',',
#  'gorgeous',
#  'fall',
#  'colors',
#  'reasons',
#  'dogwoods',
#  'always',
#  'popular',
#  'gardens',
#  'across',
#  'country',
#  '.',
#  'many',
#  'different',
#  'varieties',
#  ',',
#  'including',
#  'new',
#  'hybrids',
#  'disease-resistant',
#  ',',
#  'exist',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '15',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '9',
#  "'",
#  ',',
#  "'shop",
#  'dogwood',
#  'trees',
#  "'",
#  ',',
#  "'these",
#  'eye-catching',
#  'trees',
#  'delicate',
#  'foliage',
#  ',',
#  'interesting',
#  'bark',
#  ',',
#  'elegant',
#  ',',
#  'arching',
#  'limbs',
#  '.',
#  'foliage',
#  'comes',
#  'array',
#  'shades',
#  'pale',
#  'green',
#  'deep',
#  'burgundy',
#  '.',
#  'most',
#  'varieties',
#  'prefer',
#  'part',
#  'shade',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  '15',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '8',
#  "'",
#  ',',
#  "'shop",
#  'japanese',
#  'maple',
#  'trees',
#  "'",
#  ',',
#  "'this",
#  'lesser-known',
#  'maple',
#  'absolutely',
#  'stunning',
#  'cinnamon-brown',
#  'peeling',
#  'bark',
#  'oval',
#  'rounded',
#  'canopy',
#  'shape',
#  '.',
#  'plant',
#  'near',
#  'deck',
#  'patio',
#  'appreciate',
#  'unique',
#  'charm',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '25',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '8',
#  "'",
#  ',',
#  "'shop",
#  'paperbark',
#  'maple',
#  'trees',
#  "'",
#  ',',
#  "'this",
#  'small',
#  'tree',
#  'fragrant',
#  'clusters',
#  'white',
#  'flowers',
#  'become',
#  'purple',
#  'berries',
#  'fall',
#  '.',
#  'you',
#  'make',
#  'jam',
#  ',',
#  'share',
#  'wildlife',
#  '!',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '25',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '4',
#  '9',
#  "'",
#  ',',
#  "'shop",
#  'serviceberry',
#  'trees',
#  "'",
#  ',',
#  "'dense",
#  'branches',
#  ',',
#  'dazzling',
#  'deep',
#  'purple-red',
#  'flowers',
#  'spring',
#  ',',
#  'tiny',
#  'fruit',
#  'make',
#  'cold-hardy',
#  'crabapple',
#  'favorite',
#  'accent',
#  'garden',
#  'planted',
#  'groups',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '15',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '3',
#  '9',
#  "'",
#  ',',
#  "'shop",
#  'crabapple',
#  'trees',
#  "'",
#  ',',
#  "'once",
#  'known',
#  'plant',
#  'collectors',
#  ',',
#  'multi-stemmed',
#  'tree',
#  'becoming',
#  'popular',
#  'year-round',
#  'beauty',
#  '.',
#  'it',
#  'boasts',
#  'distinctive',
#  'curling',
#  'leaves',
#  ',',
#  'peeling',
#  'bark',
#  ',',
#  'fragrant',
#  'white',
#  'flowers',
#  'become',
#  'twisted',
#  'red',
#  'bracts',
#  '.',
#  'pollinators',
#  'love',
#  '!',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '10',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '9',
#  "'",
#  ',',
#  "'shop",
#  'seven-son',
#  'flower',
#  'trees',
#  "'",
#  ',',
#  "'this",
#  'star',
#  'southern',
#  'landscape',
#  'dark',
#  'bark',
#  ',',
#  'glossy',
#  'leaves',
#  ',',
#  'vibrant',
#  'fall',
#  'colors',
#  '.',
#  'its',
#  'showy',
#  ',',
#  'frilly',
#  'flowers',
#  'come',
#  'every',
#  'shade',
#  'pure',
#  'white',
#  'hot',
#  'pink',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '10',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '6',
#  '10',
#  "'",
#  ',',
#  "'shop",
#  'crepe',
#  'myrtle',
#  'trees',
#  "'",
#  ',',
#  "'clusters",
#  'airy',
#  ',',
#  'smoke-like',
#  'seeds',
#  'reddish',
#  'foliage',
#  'turns',
#  'orange',
#  'fall',
#  'make',
#  'beautiful',
#  'accent',
#  'tree',
#  '.',
#  'it',
#  'holds',
#  'color',
#  'season',
#  'long',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '15',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '4',
#  '8',
#  "'",
#  ',',
#  "'shop",
#  'smoke',
#  'trees',
#  "'",
#  ',',
#  "'teeny-tiny",
#  'pink',
#  'purple',
#  'flowers',
#  'cling',
#  'bare',
#  'branches',
#  'native',
#  'charmer',
#  'early',
#  'spring',
#  '.',
#  'the',
#  'pretty',
#  'heart-shaped',
#  'leaves',
#  'reddish',
#  'golden',
#  ',',
#  'depending',
#  'variety',
#  '.',
#  "'",
#  ',',
#  "'height",
#  'maturity',
#  ':',
#  'about',
#  '10',
#  '20',
#  'feet',
#  "'",
#  ',',
#  "'usda",
#  'hardiness',
#  'zones',
#  ':',
#  '5',
#  '9',
#  "'",
#  ',',
#  "'shop",
#  'redbud',
#  'trees',
#  "'",
#  ']']

# %%
from nltk.stem.wordnet import WordNetLemmatizer

lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem=PorterStemmer()

lemm_words = []

for i in range (len(filtered_words)):
    lemm_words.append(lem.lemmatize(filtered_words[i]))
    
print(lemm_words)
# Out:
# ['[', "'\\n\\t\\tcountry", 'living', 'editor', 'select', 'product', 'featured', '.', 'if', 'buy', 'link', ',', 'may', 'earn', 'commission.\\n\\n\\t\\t\\t\\t\\tmore', 'us.\\n', "'", ',', "'because", 'good', 'thing', 'really', 'come', 'small', 'package', '.', "'", ',', '``', 'if', '’', 'room', 'yard', 'mighty', 'maple', 'tree', 'towering', 'oak', 'tree', ',', 'plant', 'compact', 'tree', 'instead', '!', 'small-space', 'tree', 'pack', 'much', 'visual', 'punch', 'larger', 'sibling', ',', 'often', 'boast', 'gorgeous', 'spring', 'flower', 'vibrant', 'autumn', 'color', '.', 'that', "'s", "'ve", 'rounded', 'best', 'tree', 'small', 'garden', 'right', '.', '``', ',', "'to", 'give', 'new', 'tree', 'good', 'start', 'life', ',', 'dig', 'hole', 'twice', 'wide', 'root', 'ball', 'container', ',', 'deep', 'enough', 'sits', 'inch', 'two', 'ground', 'level', '(', 'planting', 'deep', 'common', 'mistake', '!', ')', '.', 'remove', 'burlap', ',', 'wire', ',', 'twine', 'root', 'ball', '(', 'interfere', 'root', 'growth', ')', '’', 'decompose', '(', 'nope', ',', 'even', 'burlap', ')', '.', 'spread', 'root', 'hole', ',', 'refill', 'around', 'tree', ',', 'tamp', '.', 'don', '’', 'put', 'potting', 'soil', 'additive', 'hole', ';', 'encourages', 'root', 'circle', 'around', 'inside', 'hole', ',', 'rather', 'stretching', 'native', 'soil', '.', 'water', 'tree', 'well', ',', 'mulch', '.', 'but', '’', 'mound', 'mulch', 'trunk', '(', 'called', 'volcano', 'mulching', ')', ',', 'invite', 'disease', 'insect', 'damage', '.', "'", ',', "'whether", 'tiny', 'urban', 'garden', 'small', 'backyard', ',', 'favorite', 'small', 'tree', 'plant', '.', '(', 'check', 'best', 'garden', 'plan', 'best', 'indoor', 'tree', '!', ')', "'", ',', "'showy", 'cluster', 'fragrant', 'white', 'blush-pink', 'flower', 'make', 'tree', 'real', 'showstopper', 'spring', '.', 'the', 'weeping', 'variety', 'even', 'stunning', '!', "'", ',', "'height", 'maturity', ':', 'about', '15', '20', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '5', '8', "'", ',', "'shop", 'flowering', 'cherry', 'tree', "'", ',', "'huge", 'spring', 'flower', ',', 'showy', 'red', 'fruit', 'bird', 'love', ',', 'gorgeous', 'fall', 'color', 'reason', 'dogwood', 'always', 'popular', 'garden', 'across', 'country', '.', 'many', 'different', 'variety', ',', 'including', 'new', 'hybrid', 'disease-resistant', ',', 'exist', '.', "'", ',', "'height", 'maturity', ':', 'about', '15', '20', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '5', '9', "'", ',', "'shop", 'dogwood', 'tree', "'", ',', "'these", 'eye-catching', 'tree', 'delicate', 'foliage', ',', 'interesting', 'bark', ',', 'elegant', ',', 'arching', 'limb', '.', 'foliage', 'come', 'array', 'shade', 'pale', 'green', 'deep', 'burgundy', '.', 'most', 'variety', 'prefer', 'part', 'shade', '.', "'", ',', "'height", 'maturity', ':', '15', '20', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '5', '8', "'", ',', "'shop", 'japanese', 'maple', 'tree', "'", ',', "'this", 'lesser-known', 'maple', 'absolutely', 'stunning', 'cinnamon-brown', 'peeling', 'bark', 'oval', 'rounded', 'canopy', 'shape', '.', 'plant', 'near', 'deck', 'patio', 'appreciate', 'unique', 'charm', '.', "'", ',', "'height", 'maturity', ':', 'about', '25', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '5', '8', "'", ',', "'shop", 'paperbark', 'maple', 'tree', "'", ',', "'this", 'small', 'tree', 'fragrant', 'cluster', 'white', 'flower', 'become', 'purple', 'berry', 'fall', '.', 'you', 'make', 'jam', ',', 'share', 'wildlife', '!', "'", ',', "'height", 'maturity', ':', 'about', '25', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '4', '9', "'", ',', "'shop", 'serviceberry', 'tree', "'", ',', "'dense", 'branch', ',', 'dazzling', 'deep', 'purple-red', 'flower', 'spring', ',', 'tiny', 'fruit', 'make', 'cold-hardy', 'crabapple', 'favorite', 'accent', 'garden', 'planted', 'group', '.', "'", ',', "'height", 'maturity', ':', 'about', '15', '20', 'foot', "'", ',', "'usda", 'hardiness', 'zone', ':', '3', '9', "' ...

# %%
a = [",", ".", "(", ")", ";", ":", "`", "'"]

for i in a:
    lemm_words = ([s for s in lemm_words if s != i])

# %%
value = pd.value_counts(lemm_words)
print(value)
# Out:
# tree           25
# foot           10
# zone           10
# 'usda          10
# hardiness      10
# 'shop          10
# maturity       10
# 'height        10
# about           9
# flower          9
# 20              7
# 5               6
# !               6
# garden          5
# root            5
# small           5
# spring          5
# 15              5
# 9               5
# 10              4
# deep            4
# 8               4
# plant           4
# maple           4
# make            4
# ’               4
# bark            4
# white           4
# variety         4
# fall            4
#                ..
# landscape       1
# star            1
# right           1
# cold-hardy      1
# backyard        1
# redbud          1
# delicate        1
# much            1
# dark            1
# prefer          1
# seven-son       1
# becoming        1
# twice           1
# year-round      1
# earn            1
# most            1
# mound           1
# editor          1
# airy            1
# often           1
# showstopper     1
# bird            1
# thing           1
# cling           1
# refill          1
# you             1
# additive        1
# product         1
# wildlife        1
# crepe           1
# Length: 274, dtype: int64

# %%
from nltk.probability import FreqDist
fd = FreqDist(lemm_words)

print(fd)
# Out:
# <FreqDist with 274 samples and 508 outcomes>

# %%
import matplotlib.pyplot as plt
fd.plot(30, cumulative=False)
plt.show()
